# %% [markdown]
# ##Bibliotecas utilizadas

# %%
import sys
import numpy as np
import scipy
import cv2
import sklearn
import skimage
import tensorflow as tf
import matplotlib

print("Python:", sys.version)
print("NumPy:", np.__version__)
print("SciPy:", scipy.__version__)
print("OpenCV:", cv2.__version__)
print("Scikit-learn:", sklearn.__version__)
print("Scikit-image:", skimage.__version__)
print("TensorFlow:", tf.__version__)
print("Matplotlib:", matplotlib.__version__)
# Out:
# Python: 3.13.14 (tags/v3.13.14:fd17997, Jun 10 2026, 13:03:48) [MSC v.1944 64 bit (AMD64)]
# NumPy: 2.5.1
# SciPy: 1.18.0
# OpenCV: 5.0.0
# Scikit-learn: 1.9.0
# Scikit-image: 0.26.0
# TensorFlow: 2.21.0
# Matplotlib: 3.11.1

# %%
import tensorflow as tf

print(tf.__version__)
print(tf.config.list_physical_devices())
# Out:
# 2.21.0
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
import sys
print(sys.executable)
# Out:
# c:\Doutorado\termografia\.venv\Scripts\python.exe

# %%
from scipy.io import loadmat
import numpy as np
import cv2
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow import metrics as metrics
import tensorflow as tf
from tensorflow.keras import backend as K
from keras import layers, Input, Model
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization, UpSampling2D

# %% [markdown]
# ##Conjunto de dados

# %% [markdown]
# Acessibilidade (montagem) ao Google Drive do usuário para acessar o conjunto de dados

# %% [markdown]
# Obtenção dos dados (2780 imagens térmicas infravermelhas) compactadas no formato matfile (Matlab)

# %%
from pathlib import Path
from scipy.io import loadmat

DATASET_DIR = Path("../dataset")

mat_front = loadmat(
    DATASET_DIR / "COMP412-6_Front_Flash-000136.mat"
)

mat_back = loadmat(
    DATASET_DIR / "COMP412-6_Back_Flash-000137.mat"
)

# %% [markdown]
# Manipulação dos dados obtidos pelo arquivo matfile, selecionando somente as matrizes que representam cada uma das imagens (dados) do conjunto de dados

# %%
dataset_front = mat_front['temperature']
dataset_back = mat_back['temperature']

print(dataset_front.shape)
print(dataset_back.shape)
print(dataset_front.dtype)
print(dataset_back.dtype)
# Out:
# (416, 421, 1385)
# (423, 419, 1395)
# float32
# float32

# %%
print(dataset_front.shape)
print(dataset_back.shape)
# Out:
# (416, 421, 1385)
# (423, 419, 1395)

# %% [markdown]
# Transposição da matriz de dados para adequação e manipulação com as bibliotecas numéricas do python

# %%
dataset_front = np.moveaxis(dataset_front, 2, 0)
dataset_back = np.moveaxis(dataset_back, 2, 0)

# %%
print(dataset_front.shape)
print(dataset_back.shape)
# Out:
# (1385, 416, 421)
# (1395, 423, 419)

# %%
def format(percent_value):
  return '{:.2f}%\n({:.0f})'.format(percent_value, pie_data.sum() * (percent_value / 100))

pie_data = np.array([len(dataset_front), len(dataset_back)])
pie_labels = ['Front Side', 'Back Side']
explode = [0.03 for x in pie_data]
fig, ax = plt.subplots()
ax.pie(pie_data, labels = pie_labels, explode = explode, autopct = format, shadow = True, startangle = 45, textprops = {'fontsize': 14})
fig.suptitle('Quantification of Front Side Data x Back Side Data', fontsize = 14)
ax.axis('equal')
fig.set_figheight(3)
fig.set_figwidth(3)
plt.show()
pie_data.sum()
# Out:
# np.int64(2780)

# %% [markdown]
# Unificação das duas bases originais de dados

# %%
dataset = list(dataset_front) + list(dataset_back)

# %%
train_images, temp_images = train_test_split(
    dataset,
    train_size=0.8,
    random_state=0
)

valid_images, test_images = train_test_split(
    temp_images,
    test_size=0.5,
    random_state=0
)

# %% [markdown]
# Normalização dos dados

# %%
global_min = min(
    np.min(image)
    for image in train_images
)

global_max = max(
    np.max(image)
    for image in train_images
)

# %%
def normalizar(imagens, global_min, global_max):
    return [
        (image - global_min) / (global_max - global_min)
        for image in imagens
    ]

train_images = normalizar(
    train_images,
    global_min,
    global_max
)

valid_images = normalizar(
    valid_images,
    global_min,
    global_max
)

test_images = normalizar(
    test_images,
    global_min,
    global_max
)

# %%
def extrair_patches(
    imagens,
    patch_size=128,
    stride=128
):
    patches = []

    for image in imagens:
        altura, largura = image.shape

        for y in range(
            0,
            altura - patch_size + 1,
            stride
        ):
            for x in range(
                0,
                largura - patch_size + 1,
                stride
            ):
                patch = image[
                    y:y + patch_size,
                    x:x + patch_size
                ]

                patches.append(patch)

    return np.array(
        patches,
        dtype=np.float32
    )

# %%
patch_size = 128
stride = 128

x_train = extrair_patches(
    train_images,
    patch_size,
    stride
)

x_valid = extrair_patches(
    valid_images,
    patch_size,
    stride
)

x_test = extrair_patches(
    test_images,
    patch_size,
    stride
)

# %%
print("x_train:", x_train.shape, x_train.dtype)
print("x_valid:", x_valid.shape, x_valid.dtype)
print("x_test:", x_test.shape, x_test.dtype)

print("\nIntervalos:")
print("train:", np.min(x_train), np.max(x_train))
print("valid:", np.min(x_valid), np.max(x_valid))
print("test :", np.min(x_test), np.max(x_test))
# Out:
# x_train: (20016, 128, 128) float32
# x_valid: (2502, 128, 128) float32
# x_test: (2502, 128, 128) float32
#
# Intervalos:
# train: 0.0018435591 1.0
# valid: 0.006824956 0.39796573
# test : 0.004993554 0.22301514

# %% [markdown]
# Transformando o tipo do conjunto de dados de "python list" para o formato "ndarray (float32)" da biblioteca numpy (utilizado pelo Kernas - biblioteca Google para machine learning)

# %% [markdown]
# Divisão por imagem original:

# %%
x_train = np.expand_dims(x_train, axis=-1)
x_valid = np.expand_dims(x_valid, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

print("x_train:", x_train.shape)
print("x_valid:", x_valid.shape)
print("x_test:", x_test.shape)
# Out:
# x_train: (20016, 128, 128, 1)
# x_valid: (2502, 128, 128, 1)
# x_test: (2502, 128, 128, 1)

# %%
assert x_train.ndim == 4
assert x_valid.ndim == 4
assert x_test.ndim == 4

assert x_train.shape[-1] == 1
assert x_valid.shape[-1] == 1
assert x_test.shape[-1] == 1

# %% [markdown]
# Embaralhamento do conjunto de dados

# %% [markdown]
# Aplicação de ruído gaussiano nos subconjuntos de treino, validação e teste

# %%
sigma = 0.005

# %%
noise_train = np.random.normal(
    loc=0.0,
    scale=sigma,
    size=x_train.shape
).astype(np.float32)

noise_valid = np.random.normal(
    loc=0.0,
    scale=sigma,
    size=x_valid.shape
).astype(np.float32)

noise_test = np.random.normal(
    loc=0.0,
    scale=sigma,
    size=x_test.shape
).astype(np.float32)

x_train_noisy = np.clip(
    x_train + noise_train,
    0.0,
    1.0
).astype(np.float32)

x_valid_noisy = np.clip(
    x_valid + noise_valid,
    0.0,
    1.0
).astype(np.float32)

x_test_noisy = np.clip(
    x_test + noise_test,
    0.0,
    1.0
).astype(np.float32)

# %% [markdown]
# ##Apresentação das Imagens

# %% [markdown]
# Exibição das 10 primeiras imagens dos seguintes conjuntos dos dados de testes:
#
# * Original;
# * Com ruído gaussiano.

# %%
n = 10

plt.figure(figsize=(20, 4))
for i in range(1, n + 1):
    ax = plt.subplot(2, n, i)
    plt.title('Originais')
    plt.imshow(x_test[i])
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    ax = plt.subplot(2, n, i + n)
    plt.title('Ruído Gaussiano')
    plt.imshow(x_test_noisy[i])
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# ##Implementação da Arquitetura do Autoencorder CNN

# %% [markdown]
# AutoEncoder (AE) é um tipo de Rede Neural de Aprendizagem Profunda (*Deep Learning Neural Network* - DLNN ou *Deep Neural Network* - DNN), na qual seu aprendizado é não supervisionado e sua arquitetura é fundamentada nas Redes Neurais Convolucionais (*Convolutional Neural Network* - CNN).
#
# Essencialmente os autoencoders são segregados em três módulos principais: o Encoder, o Code, e o Decoder.
#
# O AE's têm como objetivo aproximar a saída aos dados da entrada. Ou seja, quanto mais a saída se assemelhar com a entrada, melhor é a capacidade de reconstrução do autoencoder. Entretanto, assim como diversas outras redes, há que se atentar a questões como Overfitting.
#
# A Figura 1 representa, diagramaticamente, a estrutura do AE e seus três pilares básicos: o Encoder, o Code e Decoder.
#
# <figure>
# <center>
# <figcaption>Figura 1: visão geral da estrutura do AutoEnconder
# </figcaption>
# <img src='https://miro.medium.com/v2/resize:fit:720/format:webp/1*Me8UpTdSuznquyF86s9xeQ.jpeg' />
# <figcaption>Fonte: https://miro.medium.com/v2/resize:fit:720/format:webp/1*Me8UpTdSuznquyF86s9xeQ.jpeg
# </figcaption>
# </center>
# </figure>
#
# Naturalmente não há motivos que justifique o interesse em uma rede neural que apresente, em sua saída, as suas entradas.
# Porém, o aspecto de grande relevância nos AE's é a codificação dos dados da entrada pelo Encoder, ou seja, o Code.
# A figura 2 ilustra um diagrama um pouco mais aprofundado e detalhado sobre a arquitetura dos AE's.
#
# <figure>
# <center>
# <figcaption>Figura 2: modelo de arquitetura do AutoEnconder
# </figcaption>
# <img src='https://lilianweng.github.io/posts/2018-08-12-vae/denoising-autoencoder-architecture.png' />
# <figcaption>Fonte: https://lilianweng.github.io/posts/2018-08-12-vae/denoising-autoencoder-architecture.png
# </figcaption>
# </center>
# </figure>
#
# Fontes:
#
# * https://www.deeplearningbook.org/contents/autoencoders.html

# %% [markdown]
# Criação das camadas de convolucão e pooling (típicas de uma CNN clássica) com kernels 3x3, funções de ativação do tipo ReLU (Unidade Linear Retificada), mantendo as mesmas dimensões dos dados da entrada

# %%
inputs = tf.keras.Input(shape=(128, 128, 1))

x = tf.keras.layers.Conv2D(
    64, 3,
    padding='same',
    activation='relu'
)(inputs)

for _ in range(5):
    x = tf.keras.layers.Conv2D(
        64, 3,
        padding='same',
        activation='relu'
    )(x)

predicted_noise = tf.keras.layers.Conv2D(
    1, 3,
    padding='same',
    activation='linear'
)(x)

model = tf.keras.Model(inputs, predicted_noise)

# %% [markdown]
# Sumário do Denoising AutoEncoder

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 128, 128, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 128, 128, 64)   │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 128, 128, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 128, 128, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 128, 128, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 128, 128, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 128, 128, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 128, 128, 1)    │           577 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 185,857 (726.00 KB)
#  Trainable params: 185,857 (726.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Compilação da CNN (AE) com a função ADAM para a otimização e a função Binary Cross-Entropy

# %%
model.compile(
    optimizer='adam',
    loss='mse'
)

# %% [markdown]
# Etapa de treinamento da CNN-AE utilizando os dados de treino e de testes, originais e com sintéticos ruídos gaussianos, 50 épocas, lotes (subgrupos) de tamanho 128 e que, a cada lote, os dados serão selecionados de forma aleatória e com reposição

# %%
callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor="val_loss",
        mode="min",
        patience=5,
        restore_best_weights=True
    ),

    tf.keras.callbacks.ModelCheckpoint(
        "melhor_modelo.keras",
        monitor="val_loss",
        mode="min",
        save_best_only=True,
        verbose=1
    ),

    tf.keras.callbacks.BackupAndRestore(
        backup_dir="./backup_treinamento"
    )
]

# %%
noise_train_target = x_train_noisy - x_train
noise_valid_target = x_valid_noisy - x_valid

history = model.fit(
    x_train_noisy,
    noise_train_target,
    epochs=50,
    batch_size=128,
    shuffle=True,
    validation_data=(
        x_valid_noisy,
        noise_valid_target
    ),
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 25s/step - loss: 2.1709e-05
# Epoch 1: val_loss improved from None to 0.00000, saving model to melhor_modelo.keras
#
# Epoch 1: finished saving model to melhor_modelo.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4069s 26s/step - loss: 2.1709e-05 - val_loss: 3.4743e-06
# Epoch 2/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 24s/step - loss: 1.8182e-06
# Epoch 2: val_loss improved from 0.00000 to 0.00000, saving model to melhor_modelo.keras
#
# Epoch 2: finished saving model to melhor_modelo.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3906s 25s/step - loss: 1.8182e-06 - val_loss: 1.3498e-06
# Epoch 3/50
#  38/157 ━━━━━━━━━━━━━━━━━━━━ 53:49 27s/step - loss: 1.3604e-06
# Epoch 3: val_loss improved from 0.00000 to 0.00000, saving model to melhor_modelo.keras
#
# Epoch 3: finished saving model to melhor_modelo.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ -6451s -41509645us/step - loss: 1.4639e-06 - val_loss: 1.2376e-06
# Epoch 4/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27s/step - loss: 1.1506e-06
# Epoch 4: val_loss improved from 0.00000 to 0.00000, saving model to melhor_modelo.keras
#
# Epoch 4: finished saving model to melhor_modelo.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4271s 27s/step - loss: 1.1506e-06 - val_loss: 1.1032e-06
# Epoch 5/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 25s/step - loss: 1.0301e-06
# Epoch 5: val_loss improved from 0.00000 to 0.00000, saving model to melhor_modelo.keras
#
# Epoch 5: finished saving model to melhor_modelo.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4005s 26s/step - loss: 1.0301e-06 - val_loss: 9.8961e-07
# Epoch 6/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 25s/step - loss: 9.4461e-07
# Epoch 6: val_loss improved from 0.00000 to 0.00000, saving model to melhor_modelo.keras
#
# Epoch 6: finished saving model to melhor_modelo.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3980s 25s/step - loss: 9.4461e-07 - val_loss: 8.9185e-07
# Epoch 7/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 24s/step - loss: 8.8365e-07
# Epoch 7: val_loss improved from 0.00000 to 0.00000, saving model to melhor_modelo.keras
#
# Epoch 7: finished saving model to melhor_modelo.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3915s 25s/step - loss: 8.8365e-07 - val_loss: 8.4827e-07
# Epoch 8/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 25s/step - loss: 8.1997e-07
# Epoch 8: val_loss improved from 0.00000 to 0.00000, saving model to melhor_modelo.keras
#
# Epoch 8: finished saving model to melhor_modelo.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4021s 26s/step - loss: 8.1997e-07 - val_loss: 7.7635e-07
# Epoch 9/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 25s/step - loss: 7.6644e-07
# Epoch 9: val_loss improved from 0.00000 to 0.00000, saving model to melhor_modelo.keras
#
# Epoch 9: finished saving model to melhor_modelo.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3983s 25s/step - loss: 7.6644e-07 - val_loss: 7.2890e-07
# Epoch 10/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 24s/step - loss: 7.1684e-06
# Epoch 10: val_loss did not improve from 0.00000
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3912s 25s/step - loss: 7.1684e-06 - val_loss: 1.7877e-06
# Epoch 11/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 24s/step - loss: 1.4298e-06
# Epoch 11: val_loss did not improve from 0.00000
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3882s 25s/step - loss: 1.4298e-06 - val_loss: 1.2029e-06
# Epoch 12/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 24s/step - loss: 1.1532e-06
# Epoch 12: val_loss did not improve from 0.00000
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3897s 25s/step - loss: 1.1532e-06 - val_loss: 1.0430e-06
# Epoch 13/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 24s/step - loss: 1.0135e-06
# Epoch 13: val_loss did not improve from 0.00000
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3904s 25s/step - loss: 1.0135e-06 - val_loss: 9.3388e-07
# Epoch 14/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 25s/step - loss: 9.1491e-07
# Epoch 14: val_loss did not improve from 0.00000
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3927s 25s/step - loss: 9.1491e-07 - val_loss: 8.4483e-07

# %% [markdown]
# ##Resultados

# %% [markdown]
# ###Inferência

# %%
predicted_noise = model.predict(x_test_noisy)

decoded_imgs = x_test_noisy - predicted_noise

decoded_imgs = np.clip(
    decoded_imgs,
    0.0,
    1.0
)
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 76s 958ms/step

# %%
from skimage.metrics import peak_signal_noise_ratio
from skimage.metrics import structural_similarity
import numpy as np

psnr_noisy = []
psnr_denoised = []

ssim_noisy = []
ssim_denoised = []

rmse_noisy = []
rmse_denoised = []

mae_noisy = []
mae_denoised = []

for original, noisy, denoised in zip(
    x_test,
    x_test_noisy,
    decoded_imgs
):

    original = np.squeeze(original)
    noisy = np.squeeze(noisy)
    denoised = np.squeeze(denoised)

    # PSNR
    psnr_noisy.append(
        peak_signal_noise_ratio(
            original,
            noisy,
            data_range=1.0
        )
    )

    psnr_denoised.append(
        peak_signal_noise_ratio(
            original,
            denoised,
            data_range=1.0
        )
    )

    # SSIM
    ssim_noisy.append(
        structural_similarity(
            original,
            noisy,
            data_range=1.0
        )
    )

    ssim_denoised.append(
        structural_similarity(
            original,
            denoised,
            data_range=1.0
        )
    )

    # RMSE
    rmse_noisy.append(
        np.sqrt(
            np.mean(
                (original - noisy) ** 2
            )
        )
    )

    rmse_denoised.append(
        np.sqrt(
            np.mean(
                (original - denoised) ** 2
            )
        )
    )

    # MAE
    mae_noisy.append(
        np.mean(
            np.abs(original - noisy)
        )
    )

    mae_denoised.append(
        np.mean(
            np.abs(original - denoised)
        )
    )

# %%
print('--- PSNR ---')
print(f'Ruidosa:     {np.mean(psnr_noisy):.4f} dB')
print(f'Restaurada:  {np.mean(psnr_denoised):.4f} dB')

print('\n--- SSIM ---')
print(f'Ruidosa:     {np.mean(ssim_noisy):.4f}')
print(f'Restaurada:  {np.mean(ssim_denoised):.4f}')

print('\n--- RMSE ---')
print(f'Ruidosa:     {np.mean(rmse_noisy):.6f}')
print(f'Restaurada:  {np.mean(rmse_denoised):.6f}')

print('\n--- MAE ---')
print(f'Ruidosa:     {np.mean(mae_noisy):.6f}')
print(f'Restaurada:  {np.mean(mae_denoised):.6f}')
# Out:
# --- PSNR ---
# Ruidosa:     46.0208 dB
# Restaurada:  61.4214 dB
#
# --- SSIM ---
# Ruidosa:     0.9729
# Restaurada:  0.9995
#
# --- RMSE ---
# Ruidosa:     0.005000
# Restaurada:  0.000851
#
# --- MAE ---
# Ruidosa:     0.003990
# Restaurada:  0.000637

# %% [markdown]
# Teste de qualidade do AE na tarefa de reconstrução das imagens do conjunto de teste

# %% [markdown]
# Exibição das 10 primeiras imagens dos seguintes conjuntos dos dados de testes:
#
# * Original;
# * Reconstruídas (recuperadas).

# %%
n = 10

plt.figure(figsize=(20, 6))

for i in range(n):
    idx = i + 43

    original = np.squeeze(x_test[idx])
    noisy = np.squeeze(x_test_noisy[idx])
    denoised = np.squeeze(decoded_imgs[idx])

    # Janela de visualização definida pela imagem original
    vmin = np.percentile(original, 1)
    vmax = np.percentile(original, 99)

    # Original
    ax = plt.subplot(3, n, i + 1)
    plt.imshow(
        original,
        cmap='gray',
        vmin=vmin,
        vmax=vmax
    )
    plt.title('Original')
    ax.axis('off')

    # Ruidosa
    ax = plt.subplot(3, n, i + 1 + n)
    plt.imshow(
        noisy,
        cmap='gray',
        vmin=vmin,
        vmax=vmax
    )
    plt.title('Ruidosa')
    ax.axis('off')

    # Restaurada
    ax = plt.subplot(3, n, i + 1 + 2*n)
    plt.imshow(
        denoised,
        cmap='gray',
        vmin=vmin,
        vmax=vmax
    )
    plt.title('Restaurada')
    ax.axis('off')

plt.tight_layout()
plt.show()
